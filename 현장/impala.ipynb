# %%
from impala.dbapi import connect

conn = connect(host = '172.31.101.61', port = 21050 , user = 'hive', password = 'hive')
cursor = conn.cursor()

cursor.execute('select * from SVC.shinhwa_tbl_hist_access limit 100')
result = cursor.fetchall()
result
# Out:
# [(284171629,
#   'SJ03-02-Q',
#   '16,17동',
#   'Q0302-01R',
#   '국세청 309',
#   'Grant access',
#   '0001741049900297',
#   'RegStatus0001',
#   '등록',
#   '1168297',
#   '현태주',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:43:30.0',
#   '2022-01-29 15:43:37.943',
#   'Q0302-01R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171628,
#   'SJ01-02-A',
#   '6동',
#   'A0107-17R',
#   '6동 1층 로비2 스피드게이트3 OUT',
#   'Grant access',
#   '0000016136020030',
#   'RegStatus0001',
#   '등록',
#   '1219922',
#   '위성화',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613061',
#   '건설안전과',
#   '',
#   '',
#   '2022-01-29 15:43:34.0',
#   '2022-01-29 15:43:33.867',
#   'A0107-17R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171631,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-01L',
#   '7-2동 피난통로 OUT',
#   'Grant access',
#   '0000013120002008',
#   'RegStatus0001',
#   '등록',
#   '1025806',
#   '강준식',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:43:35.0',
#   '2022-01-29 15:43:42.503',
#   'O0001-01L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171636,
#   'SJ02-01-I',
#   '9,10,11동',
#   'I0102a-09R',
#   '10동1-1층-주출입구(IN)',
#   'Grant access',
#   '00000000B711BDCD',
#   'RegStatus0001',
#   '등록',
#   '90118677',
#   '김은지',
#   'EmpType0006',
#   '상시출입자',
#   '1352000',
#   '보건복지부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:43:36.0',
#   '2022-01-29 15:43:41.753',
#   'I0102a-09R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171627,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0104-02R',
#   '2동-1 1층 로비 주출입구',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:43:43.0',
#   '2022-01-29 15:43:36.943',
#   'E0104-02R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171633,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0101-16L',
#   '2동 1층 로비1 스피드 게이트1 IN',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:43:44.0',
#   '2022-01-29 15:43:52.287',
#   'E0101-16L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171634,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0601-16R',
#   '17동 602',
#   'Grant access',
#   '0000001661000440',
#   'RegStatus0001',
#   '등록',
#   '1225500',
#   '조용석',
#   'EmpType0001',
#   '공무원',
#   '1661000',
#   '소방청',
#   '1661001',
#   '청장',
#   '',
#   '',
#   '2022-01-29 15:43:50.0',
#   '2022-01-29 15:43:58.02',
#   'R0601-16R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171637,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0103-03L',
#   'KTV 125',
#   'Grant access',
#   '000000007BDA2B22',
#   'RegStatus0001',
#   '등록',
#   '90109274',
#   'KTV마스터1',
#   'EmpType0006',
#   '상시출입자',
#   'W741049',
#   '정부청사관리본부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:44:06.0',
#   '2022-01-29 15:44:13.193',
#   'R0103-03L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171635,
#   'SJ01-02-B',
#   '5동',
#   'B0603-02L',
#   '5동 624호',
#   'Grant access',
#   '0000016130003833',
#   'RegStatus0001',
#   '등록',
#   '1167137',
#   '최희정',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613623',
#   '공공택지기획과',
#   '',
#   '',
#   '2022-01-29 15:44:16.0',
#   '2022-01-29 15:44:02.397',
#   'B0603-02L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171638,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103b-17L',
#   '13-1동 스피드게이트2 - IN',
#   'Grant access',
#   '0000014501080244',
#   'RegStatus0001',
#   '등록',
#   '1165066',
#   '송경섭',
#   'EmpType0001',
#   '공무원',
#   '1450000',
#   '산업통상자원부',
#   '1450434',
#   '신산업분산에너지과',
#   '',
#   '',
#   '2022-01-29 15:44:16.0',
#   '2022-01-29 15:43:54.157',
#   'K0103b-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171640,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-06L',
#   '17동 1F 남측 주출입구',
#   'Grant access',
#   '0001741049901565',
#   'RegStatus0001',
#   '등록',
#   '1171227',
#   '이창국',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741100',
#   '세종2청사관리단',
#   '',
#   '',
#   '2022-01-29 15:44:26.0',
#   '2022-01-29 15:44:33.977',
#   'R0102-06L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171644,
#   'SJ02-02-L,M',
#   '14,15동',
#   'MRD02a-12L',
#   '15동 회전2문(남) IN',
#   'Grant access',
#   '0000137100001073',
#   'RegStatus0001',
#   '등록',
#   '1091145',
#   '이화영',
#   'EmpType0001',
#   '공무원',
#   '1371000',
#   '문화체육관광부',
#   '1371308',
#   '재정담당관',
#   '',
#   '',
#   '2022-01-29 15:44:33.0',
#   '2022-01-29 15:44:39.59',
#   'MRD02a-12L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171641,
#   'SJ02-01-I',
#   '9,10,11동',
#   'I0101a-24L',
#   '10동 로비1 스피드 게이트2 -IN',
#   'Grant access',
#   '00000000B711BDCD',
#   'RegStatus0001',
#   '등록',
#   '90118677',
#   '김은지',
#   'EmpType0006',
#   '상시출입자',
#   '1352000',
#   '보건복지부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:44:40.0',
#   '2022-01-29 15:44:15.263',
#   'I0101a-24L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171639,
#   'SJ01-02-B',
#   '5동',
#   'B0603-02L',
#   '5동 624호',
#   'Grant access',
#   '0000016130002870',
#   'RegStatus0001',
#   '등록',
#   '1064575',
#   '임현수',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613718',
#   '공공택지조사과',
#   'Position0570',
#   '환경서기보',
#   '2022-01-29 15:44:46.0',
#   '2022-01-29 15:44:26.957',
#   'B0603-02L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171642,
#   'SJ01-02-B',
#   '5동',
#   'B0605-00L',
#   '5-1동 옥상층 24번(6층식당) IN',
#   'Grant access',
#   '0000011920002194',
#   'RegStatus0001',
#   '등록',
#   '1106558',
#   '김익균',
#   'EmpType0001',
#   '공무원',
#   '1192000',
#   '해양수산부',
#   '1192046',
#   '선원정책과',
#   '',
#   '',
#   '2022-01-29 15:44:48.0',
#   '2022-01-29 15:44:43.883',
#   'B0605-00L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171645,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0101b-21L',
#   '17동-남 스피드게이트3-IN',
#   'Grant access',
#   '0001741049901565',
#   'RegStatus0001',
#   '등록',
#   '1171227',
#   '이창국',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741100',
#   '세종2청사관리단',
#   '',
#   '',
#   '2022-01-29 15:44:50.0',
#   '2022-01-29 15:44:52.663',
#   'R0101b-21L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171647,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0103-03R',
#   'KTV 126',
#   'Grant access',
#   '000000007BDA2B22',
#   'RegStatus0001',
#   '등록',
#   '90109274',
#   'KTV마스터1',
#   'EmpType0006',
#   '상시출입자',
#   'W741049',
#   '정부청사관리본부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:44:51.0',
#   '2022-01-29 15:44:58.43',
#   'R0103-03R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171643,
#   'SJ01-02-D',
#   '2,3,4동',
#   'C0602-03R',
#   '4동 604호',
#   'Grant access',
#   '0000010510004434',
#   'RegStatus0001',
#   '등록',
#   '1000950',
#   '이동각',
#   'EmpType0001',
#   '공무원',
#   '1051000',
#   '기획재정부',
#   '1051296',
#   '재정성과평가과',
#   'Position0091',
#   '6급',
#   '2022-01-29 15:44:52.0',
#   '2022-01-29 15:44:49.237',
#   'C0602-03R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171646,
#   'SJ01-02-A',
#   '6동',
#   'A0108-21R',
#   '6동 1층 로비3 스피드게이트2 OUT',
#   'Grant access',
#   '0001741049901352',
#   'RegStatus0001',
#   '등록',
#   '1171014',
#   '윤태호',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:44:55.0',
#   '2022-01-29 15:44:57.103',
#   'A0108-21R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171648,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0101b-19L',
#   '17동-남 스피드게이트4-OUT',
#   'Grant access',
#   '0000137103760005',
#   'RegStatus0001',
#   '등록',
#   '1240020',
#   '오승현',
#   'EmpType0010',
#   '공무직원증',
#   'W371037',
#   '한국정책방송원',
#   'W371529',
#   '기획편성부',
#   '',
#   '',
#   '2022-01-29 15:45:00.0',
#   '2022-01-29 15:45:02.46',
#   'R0101b-19L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171656,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103a-21L',
#   '13-1동 1F 옥외 계단실2',
#   'Grant access',
#   '0001741049901837',
#   'RegStatus0001',
#   '등록',
#   '1171499',
#   '김양균',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:45:04.0',
#   '2022-01-29 15:45:11.593',
#   'K0103a-21L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171649,
#   'SJ03-01-O',
#   '7,8동',
#   'N0701-19L',
#   '8동 옥상층 42번 IN',
#   'Grant access',
#   '0000011401002275',
#   'RegStatus0001',
#   '등록',
#   '1002453',
#   '조재훈',
#   'EmpType0001',
#   '공무원',
#   '1140100',
#   '국민권익위원회',
#   '1140228',
#   '국토해양심판과',
#   '',
#   '',
#   '2022-01-29 15:45:06.0',
#   '2022-01-29 15:45:13.53',
#   'N0701-19L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171651,
#   'SJ03-01-O',
#   '7,8동',
#   'N0001-00L',
#   '8동 피난통로1 IN',
#   'Grant access',
#   '0000013120002008',
#   'RegStatus0001',
#   '등록',
#   '1025806',
#   '강준식',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:45:08.0',
#   '2022-01-29 15:45:16.0',
#   'N0001-00L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171652,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-05L',
#   '7-2동 B1F 방풍실1 OUT',
#   'Grant access',
#   '0001741049901499',
#   'RegStatus0001',
#   '등록',
#   '1171161',
#   '곽용근',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741446',
#   '시설관리과',
#   '',
#   '',
#   '2022-01-29 15:45:11.0',
#   '2022-01-29 15:45:18.58',
#   'O0001-05L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171653,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-17R',
#   '7동-2 지하1층 EV19 OUT',
#   'Grant access',
#   '0001741049901499',
#   'RegStatus0001',
#   '등록',
#   '1171161',
#   '곽용근',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741446',
#   '시설관리과',
#   '',
#   '',
#   '2022-01-29 15:45:16.0',
#   '2022-01-29 15:45:23.973',
#   'O0001-17R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171654,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0101b-19R',
#   '17동-남 스피드게이트3-OUT',
#   'Grant access',
#   '0001741049901565',
#   'RegStatus0001',
#   '등록',
#   '1171227',
#   '이창국',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741100',
#   '세종2청사관리단',
#   '',
#   '',
#   '2022-01-29 15:45:25.0',
#   '2022-01-29 15:45:27.68',
#   'R0101b-19R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171657,
#   'SJ01-02-B',
#   '5동',
#   'B0103-02L',
#   '5동2-1층-주출입구1(IN)',
#   'Grant access',
#   '0001741049901776',
#   'RegStatus0001',
#   '등록',
#   '1171438',
#   '이종민',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:45:34.0',
#   '2022-01-29 15:45:44.527',
#   'B0103-02L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171660,
#   'SJ02-02-L,M',
#   '14,15동',
#   'MRD02a-14R',
#   '15동-1층-주출입구(IN)',
#   'Grant access',
#   '0000137100001073',
#   'RegStatus0001',
#   '등록',
#   '1091145',
#   '이화영',
#   'EmpType0001',
#   '공무원',
#   '1371000',
#   '문화체육관광부',
#   '1371308',
#   '재정담당관',
#   '',
#   '',
#   '2022-01-29 15:45:37.0',
#   '2022-01-29 15:45:42.693',
#   'MRD02a-14R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171650,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0005-01R',
#   '2동 지하1층 피난 공동구 201번(1동방향)',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:45:39.0',
#   '2022-01-29 15:45:16.71',
#   'E0005-01R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171659,
#   'SJ01-01',
#   '1동',
#   '1202L',
#   '1-B동 2층 228호 방송실',
#   'Grant access',
#   '0001741049901639',
#   'RegStatus0001',
#   '등록',
#   '1171301',
#   '이병우',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:45:40.0',
#   '2022-01-29 15:45:45.953',
#   '1202L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171663,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103b-27R',
#   '13동-1 회전2문(서-2) IN',
#   'Grant access',
#   '0001741049900072',
#   'RegStatus0001',
#   '등록',
#   '1168072',
#   '김홍용',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:45:40.0',
#   '2022-01-29 15:45:45.447',
#   'K0103b-27R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171605,
#   'SJ02-02-K',
#   '12,13동',
#   'KRD03b-25L',
#   '13동-1 회전2문(서-1) IN',
#   'Grant access',
#   '0001741049901837',
#   'RegStatus0001',
#   '등록',
#   '1171499',
#   '김양균',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:41:04.0',
#   '2022-01-29 15:41:08.67',
#   'KRD03b-25L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171599,
#   'SJ01-02-B',
#   '5동',
#   'B0003-01L',
#   '5동 지하1층 중앙감시실',
#   'Grant access',
#   '0001741049901414',
#   'RegStatus0001',
#   '등록',
#   '1171076',
#   '육재성',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:41:11.0',
#   '2022-01-29 15:41:21.863',
#   'B0003-01L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171602,
#   'SJ03-01-O',
#   '7,8동',
#   'N0501-06L',
#   '8동 5층 연결통로 129번(7동방향) OUT',
#   'Grant access',
#   '0000011401002522',
#   'RegStatus0001',
#   '등록',
#   '1257074',
#   '강재영',
#   'EmpType0001',
#   '공무원',
#   '1140100',
#   '국민권익위원회',
#   '1140102',
#   '상임위원',
#   '',
#   '',
#   '2022-01-29 15:41:24.0',
#   '2022-01-29 15:41:32.997',
#   'N0501-06L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171606,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0004a-25L',
#   '14동 B1F 방풍실2',
#   'Grant access',
#   '0001741049900264',
#   'RegStatus0001',
#   '등록',
#   '1168264',
#   '조을숙',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:41:25.0',
#   '2022-01-29 15:41:31.53',
#   'L0004a-25L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171604,
#   'SJ01-02-B',
#   '5동',
#   'B0003-17L',
#   '5동 회전2문(서)-좌 IN',
#   'Grant access',
#   '0000016130002870',
#   'RegStatus0001',
#   '등록',
#   '1064575',
#   '임현수',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613718',
#   '공공택지조사과',
#   'Position0570',
#   '환경서기보',
#   '2022-01-29 15:41:27.0',
#   '2022-01-29 15:41:36.77',
#   'B0003-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171600,
#   'SJ01-02-A',
#   '6동',
#   'A0303-01L',
#   '6동 305호',
#   'Grant access',
#   '0000001670000794',
#   'RegStatus0001',
#   '등록',
#   '1068536',
#   '서강석',
#   'EmpType0001',
#   '공무원',
#   '1670000',
#   '행정중심복합도시건설청',
#   '1670054',
#   '기획재정담당관',
#   'Position0018',
#   '행정주사보',
#   '2022-01-29 15:41:31.0',
#   '2022-01-29 15:41:26.243',
#   'A0303-01L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171607,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0004a-23R',
#   '14동2-B1-EV41(IN)',
#   'Grant access',
#   '0001741049900264',
#   'RegStatus0001',
#   '등록',
#   '1168264',
#   '조을숙',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:41:33.0',
#   '2022-01-29 15:41:41.093',
#   'L0004a-23R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171603,
#   'SJ01-02-A',
#   '6동',
#   'A0107-17L',
#   '6동 1층 로비2 스피드게이트3 IN',
#   'Grant access',
#   '0001741049901352',
#   'RegStatus0001',
#   '등록',
#   '1171014',
#   '윤태호',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:41:36.0',
#   '2022-01-29 15:41:35.667',
#   'A0107-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171598,
#   'SJ01-02-B',
#   '5동',
#   'B0705-21R',
#   '5-3동 옥상층 23번(7층) OUT',
#   'Grant access',
#   '00000000600AC65E',
#   'RegStatus0001',
#   '등록',
#   '90111220',
#   '현정우',
#   'EmpType0006',
#   '상시출입자',
#   '1543000',
#   '농림축산식품부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:41:38.0',
#   '2022-01-29 15:41:19.457',
#   'B0705-21R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171601,
#   'SJ01-02-B',
#   '5동',
#   'B0705-18R',
#   '5-3동 옥상층 17번 OUT',
#   'Grant access',
#   '00000000600AC65E',
#   'RegStatus0001',
#   '등록',
#   '90111220',
#   '현정우',
#   'EmpType0006',
#   '상시출입자',
#   '1543000',
#   '농림축산식품부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:41:51.0',
#   '2022-01-29 15:41:26.613',
#   'B0705-18R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171610,
#   'SJ03-01-O',
#   '7,8동',
#   'N0701-19R',
#   '8동 옥상층 42번 OUT',
#   'Grant access',
#   '0000011401002275',
#   'RegStatus0001',
#   '등록',
#   '1002453',
#   '조재훈',
#   'EmpType0001',
#   '공무원',
#   '1140100',
#   '국민권익위원회',
#   '1140228',
#   '국토해양심판과',
#   '',
#   '',
#   '2022-01-29 15:41:52.0',
#   '2022-01-29 15:42:01.043',
#   'N0701-19R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171613,
#   'SJ02-02-K',
#   '12,13동',
#   'K0702b-01R',
#   '13동 702',
#   'Grant access',
#   '0000016130003714',
#   'RegStatus0001',
#   '등록',
#   '1065366',
#   '정인원',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613435',
#   '사무국',
#   'Position0018',
#   '행정주사보',
#   '2022-01-29 15:41:54.0',
#   '2022-01-29 15:42:01.727',
#   'K0702b-01R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171608,
#   'SJ01-02-B',
#   '5동',
#   'B0605-00RN',
#   '5-1동 옥상층 24번(6층식당) OUT',
#   'Grant access',
#   '0001741049901363',
#   'RegStatus0001',
#   '등록',
#   '1171025',
#   '강진산',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:42:02.0',
#   '2022-01-29 15:41:54.713',
#   'B0605-00RN',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171611,
#   'SJ03-01-O',
#   '7,8동',
#   'O0501-01L',
#   '7동 5층 연결통로 125번(8동방향) OUT',
#   'Grant access',
#   '0000011401002522',
#   'RegStatus0001',
#   '등록',
#   '1257074',
#   '강재영',
#   'EmpType0001',
#   '공무원',
#   '1140100',
#   '국민권익위원회',
#   '1140102',
#   '상임위원',
#   '',
#   '',
#   '2022-01-29 15:42:05.0',
#   '2022-01-29 15:42:12.17',
#   'O0501-01L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171609,
#   'SJ01-02-B',
#   '5동',
#   'B0602-00L',
#   '5동 6층 연결통로 117번(6동방향) OUT',
#   'Grant access',
#   '0000016130003833',
#   'RegStatus0001',
#   '등록',
#   '1167137',
#   '최희정',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613623',
#   '공공택지기획과',
#   '',
#   '',
#   '2022-01-29 15:42:23.0',
#   '2022-01-29 15:41:58.963',
#   'B0602-00L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171612,
#   'SJ03-01-O',
#   '7,8동',
#   'O0501-03L',
#   '7-2동 510',
#   'Grant access',
#   '0000011401002522',
#   'RegStatus0001',
#   '등록',
#   '1257074',
#   '강재영',
#   'EmpType0001',
#   '공무원',
#   '1140100',
#   '국민권익위원회',
#   '1140102',
#   '상임위원',
#   '',
#   '',
#   '2022-01-29 15:42:23.0',
#   '2022-01-29 15:42:30.267',
#   'O0501-03L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171614,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0103-10L',
#   'KTV 121',
#   'Grant access',
#   '000000007BDA2B22',
#   'RegStatus0001',
#   '등록',
#   '90109274',
#   'KTV마스터1',
#   'EmpType0006',
#   '상시출입자',
#   'W741049',
#   '정부청사관리본부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:42:27.0',
#   '2022-01-29 15:42:35.253',
#   'R0103-10L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171621,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103b-27R',
#   '13동-1 회전2문(서-2) IN',
#   'Grant access',
#   '0000014501080244',
#   'RegStatus0001',
#   '등록',
#   '1165066',
#   '송경섭',
#   'EmpType0001',
#   '공무원',
#   '1450000',
#   '산업통상자원부',
#   '1450434',
#   '신산업분산에너지과',
#   '',
#   '',
#   '2022-01-29 15:42:30.0',
#   '2022-01-29 15:42:36.733',
#   'K0103b-27R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171615,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0104a-13L',
#   '14-2동 스피드 게이트 2 - IN',
#   'Grant access',
#   '0001741049900264',
#   'RegStatus0001',
#   '등록',
#   '1168264',
#   '조을숙',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:42:34.0',
#   '2022-01-29 15:42:27.597',
#   'L0104a-13L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171616,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0101-16R',
#   '2동 1층 로비1 스피드 게이트1 OUT',
#   'Grant access',
#   '0000011300001356',
#   'RegStatus0001',
#   '등록',
#   '1000885',
#   '송명현',
#   'EmpType0001',
#   '공무원',
#   '1130000',
#   '공정거래위원회',
#   '1130272',
#   '약관심사과',
#   'Position0261',
#   '행정사무관',
#   '2022-01-29 15:42:34.0',
#   '2022-01-29 15:42:41.797',
#   'E0101-16R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171617,
#   'SJ01-02-A',
#   '6동',
#   'A0107-19R',
#   '6동 1층 로비2 스피드게이트1 OUT',
#   'Grant access',
#   '0000016130002496',
#   'RegStatus0001',
#   '등록',
#   '1067125',
#   '김범규',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613452',
#   '복합도시정책과',
#   'Position0018',
#   '행정주사보',
#   '2022-01-29 15:42:34.0',
#   '2022-01-29 15:42:39.543',
#   'A0107-19R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171623,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103a-21L',
#   '13-1동 1F 옥외 계단실2',
#   'Grant access',
#   '0001741049901847',
#   'RegStatus0001',
#   '등록',
#   '1171509',
#   '박홍희',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:42:34.0',
#   '2022-01-29 15:42:44.937',
#   'K0103a-21L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171619,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0401-18L',
#   '2-2동 옥상층 6번(EV12·13호기/6층) IN',
#   'Grant access',
#   '0001741049902656',
#   'RegStatus0001',
#   '등록',
#   '1234134',
#   '권추택',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:42:48.0',
#   '2022-01-29 15:43:04.22',
#   'E0401-18L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171622,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0401a-09L',
#   '14-1동 4층 연결통로 156번(13동방향) OUT',
#   'Grant access',
#   '0001741049903108',
#   'RegStatus0001',
#   '등록',
#   '1279864',
#   '오진석',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741446',
#   '시설관리과',
#   '',
#   '',
#   '2022-01-29 15:42:53.0',
#   '2022-01-29 15:42:58.673',
#   'L0401a-09L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171618,
#   'SJ01-02-B',
#   '5동',
#   'B0103-16L',
#   '5동 로비2 스피드게이트1 IN',
#   'Grant access',
#   '0000016130002870',
#   'RegStatus0001',
#   '등록',
#   '1064575',
#   '임현수',
#   'EmpType0001',
#   '공무원',
#   '1613000',
#   '국토교통부',
#   '1613718',
#   '공공택지조사과',
#   'Position0570',
#   '환경서기보',
#   '2022-01-29 15:42:54.0',
#   '2022-01-29 15:42:54.99',
#   'B0103-16L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171620,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0501-20L',
#   '2동 옥상 스피드게이트 입구',
#   'Grant access',
#   '0001741049902656',
#   'RegStatus0001',
#   '등록',
#   '1234134',
#   '권추택',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:43:01.0',
#   '2022-01-29 15:43:06.08',
#   'E0501-20L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171630,
#   'SJ02-01-I',
#   '9,10,11동',
#   'IRD01a-29R',
#   '10동 회전2문(남) IN',
#   'Grant access',
#   '00000000B711BDCD',
#   'RegStatus0001',
#   '등록',
#   '90118677',
#   '김은지',
#   'EmpType0006',
#   '상시출입자',
#   '1352000',
#   '보건복지부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:43:01.0',
#   '2022-01-29 15:43:11.223',
#   'IRD01a-29R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171624,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0103-05L',
#   'KTV 128',
#   'Grant access',
#   '000000007BDA2B22',
#   'RegStatus0001',
#   '등록',
#   '90109274',
#   'KTV마스터1',
#   'EmpType0006',
#   '상시출입자',
#   'W741049',
#   '정부청사관리본부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:43:09.0',
#   '2022-01-29 15:43:18.52',
#   'R0103-05L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171625,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-17L',
#   '7동-2 지하1층 EV19 IN',
#   'Grant access',
#   '0000013120002008',
#   'RegStatus0001',
#   '등록',
#   '1025806',
#   '강준식',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:43:13.0',
#   '2022-01-29 15:43:22.253',
#   'O0001-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171632,
#   'SJ02-02-K',
#   '12,13동',
#   'K0602a-09R',
#   '12동 604',
#   'Grant access',
#   '0000014500003116',
#   'RegStatus0001',
#   '등록',
#   '1186070',
#   '이기성',
#   'EmpType0001',
#   '공무원',
#   '1450000',
#   '산업통상자원부',
#   '1450235',
#   '정보보호담당관',
#   '',
#   '',
#   '2022-01-29 15:43:13.0',
#   '2022-01-29 15:43:20.273',
#   'K0602a-09R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171626,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-05R',
#   '7-2동 B1F 방풍실1 IN',
#   'Grant access',
#   '0000013120002008',
#   'RegStatus0001',
#   '등록',
#   '1025806',
#   '강준식',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:43:17.0',
#   '2022-01-29 15:43:24.457',
#   'O0001-05R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171688,
#   'SJ02-01-I',
#   '9,10,11동',
#   'J0101a-21R',
#   '11동 로비1 스피드 게이트 2-OUT',
#   'Grant access',
#   '0000001492130320',
#   'RegStatus0001',
#   '등록',
#   '1274484',
#   '변재연',
#   'EmpType0001',
#   '공무원',
#   '1492000',
#   '고용노동부',
#   '1494601',
#   '교섭대표결정과',
#   '',
#   '',
#   '2022-01-29 15:48:05.0',
#   '2022-01-29 15:47:38.14',
#   'J0101a-21R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171699,
#   'SJ02-01-I',
#   '9,10,11동',
#   'H0101a-25R',
#   '9동 회전1문(서) IN',
#   'Grant access',
#   '0000135200001593',
#   'RegStatus0001',
#   '등록',
#   '1102720',
#   '박강수',
#   'EmpType0001',
#   '공무원',
#   '1352000',
#   '보건복지부',
#   '1352732',
#   '코로나바이러스감염증-19중앙사고수습본부',
#   '',
#   '',
#   '2022-01-29 15:48:05.0',
#   '2022-01-29 15:48:10.697',
#   'H0101a-25R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171695,
#   'SJ01-01',
#   '1동',
#   '0303R',
#   '1동2-B1-EV5(IN)',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:48:11.0',
#   '2022-01-29 15:48:18.727',
#   '0303R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171691,
#   'SJ02-02-K',
#   '12,13동',
#   'K0103b-17L',
#   '13-1동 스피드게이트2 - IN',
#   'Grant access',
#   '0000014500003286',
#   'RegStatus0001',
#   '등록',
#   '1035878',
#   '박이용',
#   'EmpType0001',
#   '공무원',
#   '1450000',
#   '산업통상자원부',
#   '1450406',
#   '전자전기과',
#   '',
#   '',
#   '2022-01-29 15:48:13.0',
#   '2022-01-29 15:47:43.773',
#   'K0103b-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171692,
#   'SJ01-01',
#   '1동',
#   '0330L',
#   '1-B동 B1층 스피드게이트 입구',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:48:15.0',
#   '2022-01-29 15:48:09.54',
#   '0330L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171697,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0004a-25L',
#   '14동 B1F 방풍실2',
#   'Grant access',
#   '0001741049900067',
#   'RegStatus0001',
#   '등록',
#   '1168067',
#   '김태림',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:48:17.0',
#   '2022-01-29 15:48:23.06',
#   'L0004a-25L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171694,
#   'SJ01-02-B',
#   '5동',
#   'B0103-17L',
#   '5동 로비2 스피드게이트2 IN',
#   'Grant access',
#   '0000015430001792',
#   'RegStatus0001',
#   '등록',
#   '1070834',
#   '박정훈',
#   'EmpType0001',
#   '공무원',
#   '1543000',
#   '농림축산식품부',
#   '1543401',
#   '방역정책국',
#   'Position0323',
#   '과장/기술서기관',
#   '2022-01-29 15:48:21.0',
#   '2022-01-29 15:48:22.853',
#   'B0103-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171696,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-19L',
#   '17-2동 옥외 북측 회전문(우) IN',
#   'Grant access',
#   '0000001750000785',
#   'RegStatus0001',
#   '등록',
#   '1115429',
#   '박두진',
#   'EmpType0001',
#   '공무원',
#   '1741000',
#   '행정안전부',
#   '1741264',
#   '재난영향분석과',
#   '',
#   '',
#   '2022-01-29 15:48:22.0',
#   '2022-01-29 15:48:30.643',
#   'R0102-19L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171700,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0004a-23R',
#   '14동2-B1-EV41(IN)',
#   'Grant access',
#   '0001741049900067',
#   'RegStatus0001',
#   '등록',
#   '1168067',
#   '김태림',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:48:24.0',
#   '2022-01-29 15:48:31.517',
#   'L0004a-23R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171707,
#   'SJ01-02-D',
#   '2,3,4동',
#   'D0101-18L',
#   '3동 1층 스피드게이트1 IN',
#   'Grant access',
#   '0000001741049440',
#   'RegStatus0001',
#   '등록',
#   '1279160',
#   '신영상',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:48:30.0',
#   '2022-01-29 15:49:12.883',
#   'D0101-18L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171698,
#   'SJ01-01',
#   '1동',
#   '0804L',
#   '1-B동 1층 스피드게이트1 출구',
#   'Grant access',
#   '0001741049901639',
#   'RegStatus0001',
#   '등록',
#   '1171301',
#   '이병우',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:48:35.0',
#   '2022-01-29 15:48:30.48',
#   '0804L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171702,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-07L',
#   '17동 1F  북측 주출입구 좌',
#   'Grant access',
#   '0000001750000785',
#   'RegStatus0001',
#   '등록',
#   '1115429',
#   '박두진',
#   'EmpType0001',
#   '공무원',
#   '1741000',
#   '행정안전부',
#   '1741264',
#   '재난영향분석과',
#   '',
#   '',
#   '2022-01-29 15:48:39.0',
#   '2022-01-29 15:48:46.3',
#   'R0102-07L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171704,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-00R',
#   '17동 행안부 1층 보안자동문',
#   'Grant access',
#   '00000000B3DC8BCD',
#   'RegStatus0001',
#   '등록',
#   '90118030',
#   '최영재',
#   'EmpType0006',
#   '상시출입자',
#   '1741000',
#   '행정안전부',
#   '0000000',
#   '일반출입증',
#   '',
#   '',
#   '2022-01-29 15:48:43.0',
#   '2022-01-29 15:48:50.893',
#   'R0102-00R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171703,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0103-17L',
#   '2동 1층 로비2 스피드 게이트2 IN',
#   'Grant access',
#   '0000011300001673',
#   'RegStatus0001',
#   '등록',
#   '1103456',
#   '황영경',
#   'EmpType0001',
#   '공무원',
#   '1130000',
#   '공정거래위원회',
#   '1130000',
#   '공정거래위원회',
#   '',
#   '',
#   '2022-01-29 15:48:44.0',
#   '2022-01-29 15:48:48.183',
#   'E0103-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171701,
#   'SJ01-02-D',
#   '2,3,4동',
#   'C0604-03R',
#   '4동 622호',
#   'Grant access',
#   '0000010510005873',
#   'RegStatus0001',
#   '등록',
#   '1000867',
#   '박민희',
#   'EmpType0001',
#   '공무원',
#   '1051000',
#   '기획재정부',
#   '1051123',
#   '운영지원과',
#   'Position0218',
#   '9급',
#   '2022-01-29 15:48:47.0',
#   '2022-01-29 15:48:45.103',
#   'C0604-03R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171706,
#   'SJ03-01-O',
#   '7,8동',
#   'O0201-05L',
#   '7동2-1층-주출입구(IN)',
#   'Grant access',
#   '0000015430001379',
#   'RegStatus0001',
#   '등록',
#   '1060312',
#   '류성훈',
#   'EmpType0001',
#   '공무원',
#   '1092000',
#   '국무조정실',
#   '1092026',
#   '농림국토해양정책관',
#   'Position0014',
#   '행정주사',
#   '2022-01-29 15:48:51.0',
#   '2022-01-29 15:48:59.417',
#   'O0201-05L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171710,
#   'SJ01-02-D',
#   '2,3,4동',
#   'D0101-02L',
#   '3동-1층-주출입구1(IN)',
#   'Grant access',
#   '0000001741049440',
#   'RegStatus0001',
#   '등록',
#   '1279160',
#   '신영상',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:48:54.0',
#   '2022-01-29 15:49:15.18',
#   'D0101-02L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171713,
#   'SJ02-01-I',
#   '9,10,11동',
#   'H0101a-06R',
#   '9동-1층-주출입구(IN)',
#   'Grant access',
#   '0000135200001593',
#   'RegStatus0001',
#   '등록',
#   '1102720',
#   '박강수',
#   'EmpType0001',
#   '공무원',
#   '1352000',
#   '보건복지부',
#   '1352732',
#   '코로나바이러스감염증-19중앙사고수습본부',
#   '',
#   '',
#   '2022-01-29 15:48:54.0',
#   '2022-01-29 15:49:06.14',
#   'H0101a-06R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171705,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-04L',
#   '17동-북 스피드게이트2-IN',
#   'Grant access',
#   '0000001750000785',
#   'RegStatus0001',
#   '등록',
#   '1115429',
#   '박두진',
#   'EmpType0001',
#   '공무원',
#   '1741000',
#   '행정안전부',
#   '1741264',
#   '재난영향분석과',
#   '',
#   '',
#   '2022-01-29 15:48:55.0',
#   '2022-01-29 15:48:56.893',
#   'R0102-04L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171709,
#   'SJ01-01',
#   '1동',
#   '0801L',
#   '1-B동 1층 128호 방호실',
#   'Grant access',
#   '0000001741049417',
#   'RegStatus0001',
#   '등록',
#   '1025830',
#   '박상현',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:48:59.0',
#   '2022-01-29 15:49:06.157',
#   '0801L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171708,
#   'SJ03-01-O',
#   '7,8동',
#   'O0101-22R',
#   '7-2동 스피드게이트2-IN',
#   'Grant access',
#   '0000015430001379',
#   'RegStatus0001',
#   '등록',
#   '1060312',
#   '류성훈',
#   'EmpType0001',
#   '공무원',
#   '1092000',
#   '국무조정실',
#   '1092026',
#   '농림국토해양정책관',
#   'Position0014',
#   '행정주사',
#   '2022-01-29 15:49:09.0',
#   '2022-01-29 15:49:11.98',
#   'O0101-22R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284175538,
#   'SJ01-02-D',
#   '2,3,4동',
#   'D0101-19L',
#   '3동 1층 스피드게이트2 IN',
#   'Deny access - Card/PIN not found',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '2022-01-29 15:49:09.0',
#   '2022-01-29 20:34:53.293',
#   'D0101-19L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171712,
#   'SJ03-01-O',
#   '7,8동',
#   'P0701-04L',
#   '7-1동 727',
#   'Grant access',
#   '0000011700001080',
#   'RegStatus0001',
#   '등록',
#   '1185871',
#   '정선임',
#   'EmpType0001',
#   '공무원',
#   '1170000',
#   '법제처',
#   '1170184',
#   '알기쉬운법령팀',
#   '',
#   '',
#   '2022-01-29 15:49:18.0',
#   '2022-01-29 15:49:24.933',
#   'P0701-04L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171711,
#   'SJ01-02-D',
#   '2,3,4동',
#   'Reader353',
#   '3동 3층 통합상황실1',
#   'Grant access',
#   '0000001740108453',
#   'RegStatus0001',
#   '등록',
#   '1003814',
#   '백승진',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:49:23.0',
#   '2022-01-29 15:49:17.35',
#   'Reader353',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171715,
#   'SJ02-01-I',
#   '9,10,11동',
#   'I0101a-25L',
#   '10동 로비1 스피드 게이트3 -IN',
#   'Grant access',
#   '0000064700004094',
#   'RegStatus0001',
#   '등록',
#   '1302218',
#   '임현정',
#   'EmpType0001',
#   '공무원',
#   '1352000',
#   '보건복지부',
#   '1352395',
#   '장애인권익지원과',
#   '',
#   '',
#   '2022-01-29 15:49:25.0',
#   '2022-01-29 15:49:08.323',
#   'I0101a-25L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171718,
#   'SJ02-02-L,M',
#   '14,15동',
#   'MRD02a-14R',
#   '15동-1층-주출입구(IN)',
#   'Grant access',
#   '0001741049901771',
#   'RegStatus0001',
#   '등록',
#   '1171433',
#   '이용표',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:49:29.0',
#   '2022-01-29 15:49:34.837',
#   'MRD02a-14R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171714,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0104a-14L',
#   '14-2동 스피드 게이트 3 - IN',
#   'Grant access',
#   '0001741049900067',
#   'RegStatus0001',
#   '등록',
#   '1168067',
#   '김태림',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:49:31.0',
#   '2022-01-29 15:49:22.417',
#   'L0104a-14L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171716,
#   'SJ02-01-I',
#   '9,10,11동',
#   'H0101a-26L',
#   '9동 로비1 스피드게이트1-IN',
#   'Grant access',
#   '0000135200001593',
#   'RegStatus0001',
#   '등록',
#   '1102720',
#   '박강수',
#   'EmpType0001',
#   '공무원',
#   '1352000',
#   '보건복지부',
#   '1352732',
#   '코로나바이러스감염증-19중앙사고수습본부',
#   '',
#   '',
#   '2022-01-29 15:49:38.0',
#   '2022-01-29 15:49:13.193',
#   'H0101a-26L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171719,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0104a-15R',
#   '14-2동 스피드 게이트 4 - OUT',
#   'Grant access',
#   '0000013420001866',
#   'RegStatus0001',
#   '등록',
#   '1140103',
#   '이영진',
#   'EmpType0001',
#   '공무원',
#   '1342000',
#   '교육부',
#   '1342204',
#   '학생건강정책과',
#   '',
#   '',
#   '2022-01-29 15:50:03.0',
#   '2022-01-29 15:49:56.457',
#   'L0104a-15R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171720,
#   'SJ02-02-L,M',
#   '14,15동',
#   'L0104a-13R',
#   '14-2동 스피드 게이트 2 - OUT',
#   'Grant access',
#   '0000013420001590',
#   'RegStatus0001',
#   '등록',
#   '1027337',
#   '김동로',
#   'EmpType0001',
#   '공무원',
#   '1342000',
#   '교육부',
#   '1342204',
#   '학생건강정책과',
#   '',
#   '',
#   '2022-01-29 15:50:07.0',
#   '2022-01-29 15:49:56.723',
#   'L0104a-13R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171717,
#   'SJ01-02-D',
#   '2,3,4동',
#   'Reader353',
#   '3동 3층 통합상황실1',
#   'Grant access',
#   '0000001741049440',
#   'RegStatus0001',
#   '등록',
#   '1279160',
#   '신영상',
#   'EmpType0001',
#   '공무원',
#   'W741049',
#   '정부청사관리본부',
#   'W741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:50:09.0',
#   '2022-01-29 15:49:43.797',
#   'Reader353',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171655,
#   'SJ01-02-B',
#   '5동',
#   'B0603-03L',
#   '5-2동 옥상층 25번(6층식당) IN',
#   'Grant access',
#   '0001741049901363',
#   'RegStatus0001',
#   '등록',
#   '1171025',
#   '강진산',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741097',
#   '시설총괄과',
#   '',
#   '',
#   '2022-01-29 15:45:44.0',
#   '2022-01-29 15:45:28.167',
#   'B0603-03L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171661,
#   'SJ01-02-D',
#   '2,3,4동',
#   'E0001-16R',
#   '2동-2 지하1층 미화하역장 OUT',
#   'Grant access',
#   '0001741049902656',
#   'RegStatus0001',
#   '등록',
#   '1234134',
#   '권추택',
#   'EmpType0010',
#   '공무직원증',
#   'W741049',
#   '정부청사관리본부',
#   'W741092',
#   '관리총괄과',
#   '',
#   '',
#   '2022-01-29 15:45:52.0',
#   '2022-01-29 15:46:01.073',
#   'E0001-16R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171658,
#   'SJ01-02-D',
#   '2,3,4동',
#   'C0604-03L',
#   '4동 608호',
#   'Grant access',
#   '0000010510005873',
#   'RegStatus0001',
#   '등록',
#   '1000867',
#   '박민희',
#   'EmpType0001',
#   '공무원',
#   '1051000',
#   '기획재정부',
#   '1051123',
#   '운영지원과',
#   'Position0218',
#   '9급',
#   '2022-01-29 15:46:00.0',
#   '2022-01-29 15:45:54.383',
#   'C0604-03L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171662,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-17L',
#   '7동-2 지하1층 EV19 IN',
#   'Grant access',
#   '0001741049901499',
#   'RegStatus0001',
#   '등록',
#   '1171161',
#   '곽용근',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741446',
#   '시설관리과',
#   '',
#   '',
#   '2022-01-29 15:46:06.0',
#   '2022-01-29 15:46:13.967',
#   'O0001-17L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171664,
#   'SJ03-01-O',
#   '7,8동',
#   'O0001-05R',
#   '7-2동 B1F 방풍실1 IN',
#   'Grant access',
#   '0001741049901499',
#   'RegStatus0001',
#   '등록',
#   '1171161',
#   '곽용근',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741446',
#   '시설관리과',
#   '',
#   '',
#   '2022-01-29 15:46:10.0',
#   '2022-01-29 15:46:17.683',
#   'O0001-05R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171665,
#   'SJ03-02-Q',
#   '16,17동',
#   'R0102-00R',
#   '17동 행안부 1층 보안자동문',
#   'Grant access',
#   '0000017500001747',
#   'RegStatus0001',
#   '등록',
#   '1068409',
#   '박용헌',
#   'EmpType0001',
#   '공무원',
#   '1741000',
#   '행정안전부',
#   '1741359',
#   '상황담당관',
#   '',
#   '',
#   '2022-01-29 15:46:11.0',
#   '2022-01-29 15:46:19.073',
#   'R0102-00R',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129'),
#  (284171672,
#   'SJ02-02-K',
#   '12,13동',
#   'K0102a-29L',
#   '12동 회전2문(북) IN',
#   'Grant access',
#   '0001741049901706',
#   'RegStatus0001',
#   '등록',
#   '1171368',
#   '정형길',
#   'EmpType0010',
#   '공무직원증',
#   '1740038',
#   '행정안전부',
#   '1741447',
#   '청사보안기획과',
#   '',
#   '',
#   '2022-01-29 15:46:15.0',
#   '2022-01-29 15:46:22.7',
#   'K0102a-29L',
#   '',
#   '',
#   '',
#   'N',
#   'JOB_AC_SHINHWA_01_20221216212101',
#   '20220129')]
