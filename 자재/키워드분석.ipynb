# %%
import pandas as pd

# %%
df = pd.read_excel('GFMS DB/FMSA10_작업지시_결과.xlsx')
cont
# Out:
#       comp_cd                 job_cd  job_tpy                         job_nm  \
# 0        SEJO           211001-00060        5             1동 307호 벽에 못 제거 요청
# 1        SEJO           211001-00053        5  1동 411호 천장 고양이 구조로 인한 텍스분리 요청
# 2        SEJO  M_202110011345461_001        3            5동 정문 도로 중앙규제봉 교체작업
# 3        SEJO  M_202110011511311_001        3   SCC홍보동 부출입구쪽 외부창옆 바닥 보도블럭 침하
# 4        SEJO           211001-00010        5      2동 438호 옆 오른쪽 1번 칸 양변기 막힘
# ...       ...                    ...      ...                            ...
# 19055    SEJO  M_202210110943434_000        3                         출입문 보수
# 19056    SEJO  M_202210111009465_000        3          방화문(플로어힌지, 피봇힌지 등) 보수
# 19057    SEJO           221011-00057        3     16동 기계실 인버터 판넬 누름 스위치 보수작업
# 19058    SEJO           221011-00044        5         16동 1층 동쪽 여자화장실 대변기 막힘
# 19059    SEJO           221011-00019        5     17-2동 7층 남자 화장실 대변기 물 계속흐름
#
# ...

# %%
job_nm = []
job_cont=[]
for i in range(len(df)):
    job_nm_contents = df['job_nm'].iloc[i]
    job_nm.append(job_nm_contents)
    job_cont_contents = df['job_cont'].iloc[i]
    job_cont.append(job_nm_contents)

# %%
job_nm
# Out:
# ['1동 307호 벽에 못 제거 요청',
#  '1동 411호 천장 고양이 구조로 인한 텍스분리 요청',
#  '5동 정문 도로 중앙규제봉 교체작업',
#  'SCC홍보동 부출입구쪽 외부창옆 바닥 보도블럭 침하',
#  '2동 438호 옆 오른쪽 1번 칸 양변기 막힘',
#  '4동 4층 사무실 정수 온수밸브 크랙누수 3층 323호 천정 누수 발생',
#  '4동6층 공조기 6번 동파방지 캡 누수',
#  ' 5동 6층 식당 세척실 세척기 가스 부스터 오작동  부픔교체및 방열기교체(보수반)',
#  '솔비타 어린이집 자람 3반 좌변기 누름 버튼 고장',
#  '2동 1구역 430호 남자화장실 비데 전열불량',
#  '4동 지하 1층 전기원휴게실내 샤워장 전등점등불량.',
#  '4동 정문 입차 측 차단기 통신보드 교체',
#  '4동 608호 정책조정기획관실 전등 점등 불량',
#  '6동 552호 운영지원과 전열불량',
#  '안내동  정문 입차측 차번인식기용 카메라조명 교체',
#  '1동 1구역 2층 복도내 거실통로유도등 점등불량 교체 작업',
#  '2-1동 옥상층 66번 CCTV PTZ 동작 불량',
#  '5-3동 1F 34번 얼굴인식단말기 동작 불량',
#  '6동 3구역 1층 로비 안내 데스크 전화 불통',
#  '철재난간대 보수',
#  '7-1동 6층 남자화장실 대변기 뚜껑 떨어짐',
#  '7동 스포츠 센터 옥상 급,배기휀 그리스 주입 및 벨트 점검',
#  '7-2동 5층 여자화장실  탕비실 수도꼭지 고장',
#  '8동 1층 복도 EHP 에어컨 경고표시등 들어옴',
#  '8동 4층 여자화장실 대변기 물 계속 흐름',
#  '9동 5-2, 5-4 남자 화장실  소변기 물이 약함',
#  '11동 소산상황실 남자 화장실 소변기 점검',
#  '11동 1층 민방위비상급수시설 기동점검',
#  '11동 옥상및 지하층 급배기 팬 점검',
#  '12동 지하 소산시설 자동제어 모니터 에러발생',
# ...
