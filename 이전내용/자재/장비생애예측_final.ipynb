# %%
import pandas as pd
from pathlib import Path
import datetime

path = Path.cwd()
path = str(path)+'/GFMS DB/'
path
# Out:
# '/Users/keumhyeonjun/Projects/행안부/자재/GFMS DB/'

# %% [markdown]
# # 데이터 불러오기

# %%
FMSA10_작업지시_결과 = pd.read_csv(path+'FMSA10_작업지시_결과_ver2.csv')

FMSA11_작업장비이력 = pd.read_excel(path + 'FMSA11_작업장비이력.xlsx')

FMSX05_장비마스터 = pd.read_csv(path + 'FMSX05_장비마스터_ver2.csv')

FMSB07_자재출고 = pd.read_excel(path + 'FMSB07_자재출고.xlsx')

FMSB03_자재마스터 = pd.read_csv(path + 'FMSB03_자재마스터_ver2.csv')

FMSB03_자재마스터.drop(['class_nm_4','class_cd_4'],axis =1,inplace = True)

FMSB03_자재마스터.rename(columns={'class_nm_3':'jajae_class_nm_3'},inplace = True)
FMSB03_자재마스터.rename(columns={'class_nm_2':'jajae_class_nm_2'},inplace = True)
FMSB03_자재마스터.rename(columns={'class_nm_1':'jajae_class_nm_1'},inplace = True)

FMSB03_자재마스터.rename(columns={'class_cd_3':'jajae_class_cd_3'},inplace = True)
FMSB03_자재마스터.rename(columns={'class_cd_2':'jajae_class_cd_2'},inplace = True)
FMSB03_자재마스터.rename(columns={'class_cd_1':'jajae_class_cd_1'},inplace = True)


FMSX05_장비마스터.rename(columns={'class_nm_4':'jangbi_class_nm_4'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_nm_3':'jangbi_class_nm_3'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_nm_2':'jangbi_class_nm_2'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_nm_1':'jangbi_class_nm_1'},inplace = True)


FMSX05_장비마스터.rename(columns={'class_cd_4':'jangbi_class_cd_4'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_cd_3':'jangbi_class_cd_3'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_cd_2':'jangbi_class_cd_2'},inplace = True)
FMSX05_장비마스터.rename(columns={'class_cd_1':'jangbi_class_cd_1'},inplace = True)

FMSA10_작업지시_결과.rename(columns={'class_nm_4':'job_class_nm_4'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_nm_3':'job_class_nm_3'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_nm_2':'job_class_nm_2'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_nm_1':'job_class_nm_1'},inplace = True)


FMSA10_작업지시_결과.rename(columns={'class_cd_4':'job_class_cd_4'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_cd_3':'job_class_cd_3'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_cd_2':'job_class_cd_2'},inplace = True)
FMSA10_작업지시_결과.rename(columns={'class_cd_1':'job_class_cd_1'},inplace = True)

fmsa10 =FMSA10_작업지시_결과[['job_cd','job_nm','job_jisi_dt','job_enddt','job_shm','job_ehm','job_class_nm_1','job_class_nm_2','job_class_nm_3','job_class_nm_4']]
fmsb03 = FMSB03_자재마스터[['mat_cd','mat_nm','jajae_class_nm_1','jajae_class_nm_2','jajae_class_nm_3','jajae_class_cd_3']]
fmsx05 = FMSX05_장비마스터[['fac_cd','fac_nm','jangbi_class_nm_1','jangbi_class_nm_2','jangbi_class_nm_3','jangbi_class_nm_4','fac_instdt']]


FMSB07_자재출고["mat_cd"] = FMSB07_자재출고["mat_cd"].astype("str")
FMSB07_자재출고["mat_cd"] = list(map(lambda x: x[:-3],FMSB07_자재출고["mat_cd"].tolist())) # FMSB03과 inner join하기 위해 mat_cd 형식 일치
fmsb03["mat_cd"] = fmsb03["mat_cd"].astype("str")
jajae = pd.merge(FMSB07_자재출고,fmsb03 ,on = 'mat_cd', how = 'inner')
jajae = jajae[['job_cd','outw_day','mat_cd','outw_qty','mat_nm_x','jajae_class_nm_1','jajae_class_nm_2','jajae_class_nm_3','jajae_class_cd_3']]


jangbi = pd.merge(FMSA11_작업장비이력, fmsx05, how='inner', on='fac_cd')
jangbi_broken = pd.merge(fmsa10,jangbi, on='job_cd',how = 'inner')

jangbi_broken.drop(['job_cont','chg_sysdt','chg_emp_no'],axis=1,inplace=True)
jangbi_broken = jangbi_broken.dropna()

jangbi_broken['자재매칭여부'] = jangbi_broken['job_cd']
arr_장비 = list(jangbi_broken['job_cd'])
arr_자재 = list(jajae['job_cd'])
#자재 매칭이 안되는 경우
arr = list(set(arr_장비)- set(arr_자재))

def function(x):
    if x in arr:
        return 0
    else:
         return 1

jangbi_broken['자재매칭여부'] = jangbi_broken['자재매칭여부'].apply(function)
df = pd.merge(jangbi_broken,jajae, on='job_cd',how = 'inner')

jangbi_jajae = df[['job_cd','job_nm','job_jisi_dt','job_enddt','job_shm','job_ehm','job_class_nm_1','job_class_nm_2','job_class_nm_3','job_class_nm_4','fac_cd','fac_nm','fac_instdt','mat_cd','mat_nm_x',
           'jangbi_class_nm_1','jangbi_class_nm_2','jangbi_class_nm_3','jangbi_class_nm_4','자재매칭여부','mat_nm_x','jajae_class_nm_1','jajae_class_nm_2','jajae_class_nm_3','jajae_class_cd_3']]
# Out:
# /var/folders/nd/cl2nzwh13zx7jdly2t5m95340000gn/T/ipykernel_7385/1566979569.py:1: DtypeWarning: Columns (59) have mixed types. Specify dtype option on import or set low_memory=False.
#   FMSA10_작업지시_결과 = pd.read_csv(path+'FMSA10_작업지시_결과_ver2.csv')
# /var/folders/nd/cl2nzwh13zx7jdly2t5m95340000gn/T/ipykernel_7385/1566979569.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fmsb03["mat_cd"] = fmsb03["mat_cd"].astype("str")

# %%
jangbi_broken
# Out:
#             job_cd                               job_nm job_jisi_dt  \
# 0     211001-00047            2동 1구역 430호 남자화장실 비데 전열불량  2021-10-01
# 3     211001-00081     1동 1구역 2층 복도내 거실통로유도등 점등불량 교체 작업  2021-10-01
# 4     211001-00070          2-1동 옥상층 66번 CCTV PTZ 동작 불량  2021-10-01
# 5     211001-00069            5-3동 1F 34번 얼굴인식단말기 동작 불량  2021-10-01
# 6     211001-00025             7-1동 6층 남자화장실 대변기 뚜껑 떨어짐  2021-10-01
# ...            ...                                  ...         ...
# 6825  221011-00020              12동 4-1 남자화장실 소변기 뒤쪽 누수  2022-10-11
# 6826  221011-00011   13동 5-7 여자화장실 오른쪽 첫번째 대변기 밑 밸브쪽 누수  2022-10-11
# 6827  221011-00066  13-2동 1층 방재실 R형 수신기 예비전원 불량 교체 (2개)  2022-10-11
# 6829  221011-00044               16동 1층 동쪽 여자화장실 대변기 막힘  2022-10-11
# 6830  221011-00019           17-2동 7층 남자 화장실 대변기 물 계속흐름  2022-10-11
#
#        job_enddt                 job_shm                 job_ehm  \
# 0     2021-10-01   2021-10-01 오후 2:30:00   2021-10-01 오후 2:40:00
# 3     2021-10-01   2021-10-01 오후 1:30:00   2021-10-01 오후 1:45:00
# 4     2021-10-01   2021-10-01 오전 9:00:00   2021-10-01 오후 5:31:00
# 5     2021-10-01   2021-10-01 오후 1:10:00   2021-10-01 오후 2:11:00
# 6     2021-10-01   2021-10-01 오전 9:20:00   2021-10-01 오전 9:40:00
# ...          ...                     ...                     ...
# 6825  2022-10-11  2022-10-11 오전 10:30:00  2022-10-11 오전 11:00:00
# 6826  2022-10-11   2022-10-11 오전 9:40:00  2022-10-11 오전 10:10:00
# 6827  2022-10-11   2022-10-11 오후 2:30:00   2022-10-11 오후 3:10:00
# 6829  2022-10-11   2022-10-11 오전 8:32:00   2022-10-11 오전 9:30:00
# 6830  2022-10-11   2022-10-11 오전 8:57:00   2022-10-11 오전 9:20:00
#
#      job_class_nm_1 job_class_nm_2 job_class_nm_3 job_class_nm_4  ...  \
# 0            2동 1구역             4층            분전반           EPS실  ...
# 3            1동 1구역             2층            유도등       거실통로 유도등  ...
# 4            2동 1구역            옥상층          방범시스템       CCTV 카메라  ...
# 5            5동 3구역             1층        출입통제시스템           얼굴인식  ...
# 6              7-1동             6층           위생설비            대변기  ...
# ...             ...            ...            ...            ...  ...
# 6825          12-3동             4층           위생설비            소변기  ...
# 6826          13-1동             5층           위생설비             비데  ...
# 6827          13-2동             1층       자동화재탐지설비            수신기  ...
# 6829            16동             1층           위생설비            대변기  ...
# 6830          17-2동             7층           위생설비            대변기  ...
#
#                  input_sysdt   input_emp_no input_scr_nm             fac_nm  \
# 0      2021-10-01 오후 3:24:08  crowonthetree      JOB_A11          LN-4E1(E)
# 3     2021-10-21 오전 10:33:08       skysen83      JOB_A11       1동  거실통로 유도등
# 4      2021-10-01 오후 5:39:22       hugh7192      JOB_A11        2동 CCTV #66
# 5      2021-10-01 오후 5:34:38      sghong923      JOB_A11      5-3동 얼굴인식 #34
# 6      2021-10-01 오후 9:33:55       kwak6400      JOB_A11  7-1동-6F 화장실(남)대변기
# ...                      ...            ...          ...                ...
# 6825   2022-10-11 오후 1:25:55     rhkdtlr761      JOB_A11            소변기 #07
# 6826  2022-10-11 오전 10:38:16     rhkdtlr761      JOB_A11          물내림비데 #30
# 6827   2022-10-11 오후 4:09:26        kjkim63      JOB_A11      13동 GR형복합식수신기
# 6829   2022-10-11 오후 2:59:13         je0303      JOB_A11    1F여2동쪽 공용대변기(5)
# 6830   2022-10-11 오후 1:42:33          as119      JOB_A11         7F남2대변기(3)
#
#      jangbi_class_nm_1 jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4  \
# 0                   전기            전력공급설비               분전반              EPS실
# 3                   방재              피난설비               유도등          거실통로 유도등
# 4                   통신              방범설비             방범시스템          CCTV 카메라
# 5                   통신              방범설비           출입통제시스템              얼굴인식
# 6                   기계          위생, 탱크설비              위생설비               대변기
# ...                ...               ...               ...               ...
# 6825                기계          위생, 탱크설비              위생설비               소변기
# 6826                기계          위생, 탱크설비              위생설비                비데
# 6827                방재              경보설비          자동화재탐지설비               수신기
# 6829                기계          위생, 탱크설비              위생설비               대변기
# 6830                기계          위생, 탱크설비              위생설비               대변기
#
#       fac_instdt 자재매칭여부
# 0     2012-09-01      0
# 3     2012-05-01      1
# 4     2019-10-25      1
# 5     2019-10-10      0
# 6     2019-11-27      0
# ...          ...    ...
# 6825  2012-03-01      0
# 6826  2012-03-01      0
# 6827  2013-11-01      1
# 6829  2014-06-01      0
# 6830  2014-06-01      0
#
# [6343 rows x 22 columns]

# %%
jangbi_broken

jangbi_broken = jangbi_broken.sort_values('job_jisi_dt')


jangbi_broken['기준일자'] = '2022-10-11'

jangbi_broken['기준일자'] = pd.to_datetime(jangbi_broken['기준일자'])
jangbi_broken['fac_instdt'] = pd.to_datetime(jangbi_broken['fac_instdt'])
jangbi_broken['job_jisi_dt'] = pd.to_datetime(jangbi_broken['job_jisi_dt'])


jangbi_broken['설치-작업간격'] = jangbi_broken['job_jisi_dt'] - jangbi_broken['fac_instdt']

def slicing(x):
    return x[:-4]
jangbi_broken['설치-작업간격'] = jangbi_broken['설치-작업간격'].astype(str)
jangbi_broken['설치-작업간격'] = jangbi_broken['설치-작업간격'].apply(slicing)
jangbi_broken['설치-작업간격'] = jangbi_broken['설치-작업간격'].astype(int)

jangbi_broken['작업-작업간격'] = 0
jangbi_broken['작업-작업간격'] = 0

jangbi_broken = jangbi_broken.sort_values(['fac_cd','설치-작업간격'])
jangbi_broken.head()
# Out:
#             job_cd                      job_nm job_jisi_dt   job_enddt  \
# 3985  220506-00021           16동 흡수식 냉동기 세관 작업  2022-05-06  2022-05-06
# 4006  220509-00008           16동 흡수식 냉동기 세관 작업  2022-05-09  2022-05-09
# 4102  220513-00042             16동 냉동기 시운전 보고서  2022-05-13  2022-05-13
# 5582  220809-00058  16동 지하2층 기계실 흡수식냉동기#1 추기작업  2022-08-09  2022-08-09
# 3986  220506-00021           16동 흡수식 냉동기 세관 작업  2022-05-06  2022-05-06
#
#                     job_shm                job_ehm job_class_nm_1  \
# 3985  2022-05-06 오전 9:00:00  2022-05-06 오후 3:00:00            16동
# 4006  2022-05-09 오전 9:00:00  2022-05-09 오전 9:30:00            16동
# 4102  2022-05-13 오후 1:00:00  2022-05-13 오후 3:00:00            16동
# 5582  2022-08-09 오후 3:00:00  2022-08-09 오후 4:00:00            16동
# 3986  2022-05-06 오전 9:00:00  2022-05-06 오후 3:00:00            16동
#
#      job_class_nm_2 job_class_nm_3 job_class_nm_4  ...     fac_nm  \
# 3985           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 4006           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 4102           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 5582           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 3986           지하2층           열원설비            냉동기  ...  흡수식냉동기#2
#
#       jangbi_class_nm_1 jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4  \
# 3985                 기계            공기조화설비              열원설비               냉동기
# 4006                 기계            공기조화설비              열원설비               냉동기
# 4102                 기계            공기조화설비              열원설비               냉동기
# 5582                 기계            공기조화설비              열원설비               냉동기
# 3986                 기계            공기조화설비              열원설비               냉동기
#
#      fac_instdt 자재매칭여부       기준일자 설치-작업간격 작업-작업간격
# 3985 2019-09-03      0 2022-10-11     976       0
# 4006 2019-09-03      1 2022-10-11     979       0
# 4102 2019-09-03      0 2022-10-11     983       0
# 5582 2019-09-03      0 2022-10-11    1071       0
# 3986 2014-02-01      0 2022-10-11    3016       0
#
# [5 rows x 25 columns]

# %%
# 작업-작업 간격 만들기
for i in range(len(jangbi_broken)):
    if i == 0:
        jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i]
    else :
        now_data = jangbi_broken['fac_cd'].iloc[i]
        past_data = jangbi_broken['fac_cd'].iloc[i-1]
        if now_data == past_data:
            jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i] - jangbi_broken['설치-작업간격'].iloc[i-1]
        else :
            jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i]
jangbi_broken.head()
# Out:
# /var/folders/nd/cl2nzwh13zx7jdly2t5m95340000gn/T/ipykernel_7385/1686177134.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i]
# /var/folders/nd/cl2nzwh13zx7jdly2t5m95340000gn/T/ipykernel_7385/1686177134.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i] - jangbi_broken['설치-작업간격'].iloc[i-1]
# /var/folders/nd/cl2nzwh13zx7jdly2t5m95340000gn/T/ipykernel_7385/1686177134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jangbi_broken['작업-작업간격'].iloc[i] = jangbi_broken['설치-작업간격'].iloc[i]
#             job_cd                      job_nm job_jisi_dt   job_enddt  \
# 3985  220506-00021           16동 흡수식 냉동기 세관 작업  2022-05-06  2022-05-06
# 4006  220509-00008           16동 흡수식 냉동기 세관 작업  2022-05-09  2022-05-09
# 4102  220513-00042             16동 냉동기 시운전 보고서  2022-05-13  2022-05-13
# 5582  220809-00058  16동 지하2층 기계실 흡수식냉동기#1 추기작업  2022-08-09  2022-08-09
# 3986  220506-00021           16동 흡수식 냉동기 세관 작업  2022-05-06  2022-05-06
#
#                     job_shm                job_ehm job_class_nm_1  \
# 3985  2022-05-06 오전 9:00:00  2022-05-06 오후 3:00:00            16동
# 4006  2022-05-09 오전 9:00:00  2022-05-09 오전 9:30:00            16동
# 4102  2022-05-13 오후 1:00:00  2022-05-13 오후 3:00:00            16동
# 5582  2022-08-09 오후 3:00:00  2022-08-09 오후 4:00:00            16동
# 3986  2022-05-06 오전 9:00:00  2022-05-06 오후 3:00:00            16동
#
#      job_class_nm_2 job_class_nm_3 job_class_nm_4  ...     fac_nm  \
# 3985           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 4006           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 4102           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 5582           지하2층           열원설비            냉동기  ...   흡수식냉동기#1
# 3986           지하2층           열원설비            냉동기  ...  흡수식냉동기#2
#
#       jangbi_class_nm_1 jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4  \
# 3985                 기계            공기조화설비              열원설비               냉동기
# 4006                 기계            공기조화설비              열원설비               냉동기
# 4102                 기계            공기조화설비              열원설비               냉동기
# 5582                 기계            공기조화설비              열원설비               냉동기
# 3986                 기계            공기조화설비              열원설비               냉동기
#
#      fac_instdt 자재매칭여부       기준일자 설치-작업간격 작업-작업간격
# 3985 2019-09-03      0 2022-10-11     976     976
# 4006 2019-09-03      1 2022-10-11     979       3
# 4102 2019-09-03      0 2022-10-11     983       4
# 5582 2019-09-03      0 2022-10-11    1071      88
# 3986 2014-02-01      0 2022-10-11    3016    3016
#
# [5 rows x 25 columns]

# %%
max_time = datetime.datetime(2022,10,11)
analysis_data = pd.merge(fmsx05,jangbi_broken[['job_jisi_dt','fac_cd','설치-작업간격','작업-작업간격','job_cd','job_nm']], on ='fac_cd', how ='left')

analysis_data['fac_instdt'] = pd.to_datetime(analysis_data['fac_instdt'])

analysis_data = analysis_data[analysis_data['fac_instdt'] <= max_time]


analysis_data['max_time'] = max_time
analysis_data['max_time'] = pd.to_datetime(analysis_data['max_time'])
analysis_data['작업-작업간격'] = analysis_data['작업-작업간격'].fillna(999999)

analysis_data['설치-작업간격'] = analysis_data['설치-작업간격'].fillna(999999)

#analysis_data.dropna(inplace = True)
def status(df):
    if df['작업-작업간격'] == 999999:
        return 0
    else :
        return 1

def 재발(df):
    if df['status'] == 1 and df['설치-작업간격'] != df['작업-작업간격']:
        return 1
    else:
        return 0

def 첫번째고장(df):
    if df['status'] == 1 and df['재발유무'] ==1 and :
        return 1
    else:
        return 0

analysis_data['status'] =analysis_data.apply(status,axis=1)



def time(df):
    x = df['작업-작업간격']
    if x == 999999:
        return int(str(df['max_time'] -  df['fac_instdt'])[:-13])
    else :
        return int(x)
def time2(df):
    x = df['설치-작업간격']
    if x == 999999:
        return int(str(df['max_time'] -  df['fac_instdt'])[:-13])
    else :
        return int(x)

analysis_data['작업-작업간격'] = analysis_data.apply(time,axis=1)
analysis_data['설치-작업간격'] = analysis_data.apply(time2,axis=1)
analysis_data['재발유무'] = analysis_data.apply(재발,axis=1)
analysis_data.head()
# Out:
#          fac_cd                       fac_nm jangbi_class_nm_1  \
# 0  200201040293  (3)세-1F-0(여)로비-화장실) 세면대 2대                 기계
# 1  200201010257                   9F여1대변기(5)                기계
# 2  200202030001                        우수조#1                기계
# 3  200105080599               배기휀#76(EF-504)                기계
# 4  200202010001                        시수조#1                기계
#
#   jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4 fac_instdt  \
# 0          위생, 탱크설비              위생설비            세면대 수전 2018-03-05
# 1          위생, 탱크설비              위생설비               대변기 2014-06-01
# 2          위생, 탱크설비              탱크설비            우수 저장조 2019-10-22
# 3            공기조화설비              환기설비               환기팬 2019-10-23
# 4          위생, 탱크설비              탱크설비            상수 저장조 2019-10-22
#
#   job_jisi_dt  설치-작업간격  작업-작업간격 job_cd job_nm   max_time  status  재발유무
# 0         NaT     1681     1681    NaN    NaN 2022-10-11       0     0
# 1         NaT     3054     3054    NaN    NaN 2022-10-11       0     0
# 2         NaT     1085     1085    NaN    NaN 2022-10-11       0     0
# 3         NaT     1084     1084    NaN    NaN 2022-10-11       0     0
# 4         NaT     1085     1085    NaN    NaN 2022-10-11       0     0

# %%
analysis_data[analysis_data['재발유무']==1]
# Out:
#              fac_cd                        fac_nm jangbi_class_nm_1  \
# 539    400201040064                      1동 입력중계기                방재
# 544    400201020085                 1동 아날로그 연기감지기                방재
# 653    600402030017                   1동 CCTV #81                통신
# 654    600402030017                   1동 CCTV #81                통신
# 655    600402030017                   1동 CCTV #81                통신
# ...             ...                           ...               ...
# 43033  200103010181                     (컨전)공조기11                기계
# 43145  200201040672  (컨전)세-4F(여)433앞-화장실) 세면대 3대                 기계
# 43146  200201040672  (컨전)세-4F(여)433앞-화장실) 세면대 3대                 기계
# 43511  400301010054                   SCC 피난구 유도등                방재
# 43515  200105040013           (컨전)악취제거기 옥상(CE-02)                기계
#
#       jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4 fac_instdt  \
# 539                경보설비          자동화재탐지설비               중계기 2012-05-01
# 544                경보설비          자동화재탐지설비               감지기 2012-05-01
# 653                방범설비             방범시스템          CCTV 카메라 2019-10-25
# 654                방범설비             방범시스템          CCTV 카메라 2019-10-25
# 655                방범설비             방범시스템          CCTV 카메라 2019-10-25
# ...                 ...               ...               ...        ...
# 43033            공기조화설비              공조설비             일반공조기 2014-05-01
# 43145          위생, 탱크설비              위생설비            세면대 수전 2014-11-01
# 43146          위생, 탱크설비              위생설비            세면대 수전 2014-11-01
# 43511              피난설비               유도등           피난구 유도등 2014-01-01
# 43515            공기조화설비              환기설비             악취제거기 2014-05-01
#
#       job_jisi_dt  설치-작업간격  작업-작업간격        job_cd  \
# 539    2021-12-28     3528       74  211228-00023
# 544    2021-12-01     3501        2  211201-00081
# 653    2021-10-17      723       12  211017-00001
# 654    2021-10-21      727        4  211021-00068
# 655    2021-10-27      733        6  211027-00059
# ...           ...      ...      ...           ...
# 43033  2022-07-05     2987      148  220705-00013
# 43145  2022-06-08     2776        1  220608-00007
# 43146  2022-07-20     2818       42  220720-00042
# 43511  2022-04-26     3037       14  220426-00033
# 43515  2022-04-12     2903       41  220412-00007
#
#                                                   job_nm   max_time  status  \
# 539    1동 1구역 지하1층 오염기계실2내 소화가스설비(모듈러) B감지기 라인 입력용 중계... 2022-10-11       1
# 544    1동 1구역 지하1층 오염기계실내 오수탱크실 상부 아날로그 감지기 (비화재건) 교체 작업 2022-10-11       1
# 653              (방호) [1동 지하1-1 지하주차장입구 81번] 카메라 오류수정 요청 2022-10-11       1
# 654                               1-1동 B1 81번 카메라 포커스 불량 2022-10-11       1
# 655                             1-1동 B1F 81번 CCTV 카메라 교체 2022-10-11       1
# ...                                                  ...        ...     ...
# 43033               컨벤션 전시동 3층 03,05,06,11번 SA.RA V밸트 교체 2022-10-11       1
# 43145            전시동 4층 419호 옆 여자장애인 화장실 세면대 배수관 탈락 보수요청 2022-10-11       1
# 43146                      컨벤션 센터 4층 여자화장실  세면대 2곳 하부 누수 2022-10-11       1
# 43511             scc 전시동 5층 2번계단 입구 앞 피난구유도등 점등불량 교체 작업 2022-10-11       1
# 43515              컨벤션 전시동, 지원동 옥상 악취제거기 필터 교체 및 유분필터 청소 2022-10-11       1
#
#        재발유무
# 539       1
# 544       1
# 653       1
# 654       1
# 655       1
# ...     ...
# 43033     1
# 43145     1
# 43146     1
# 43511     1
# 43515     1
#
# [2777 rows x 15 columns]

# %% [markdown]
# # 기간 내 고장 확률 산출

# %%
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter

plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
장비명 = '위생설비'
input_data = analysis_data[analysis_data['jangbi_class_nm_3']==장비명]


kmf = KaplanMeierFitter()
input_data.sort_values(by='작업-작업간격', ascending=True)
kmf.fit(durations=input_data['작업-작업간격'], event_observed=input_data['status'])
kmf.plot_survival_function()
plt.title(장비명+' 기간별 정상 확률')
기간_일 = 30
print(f'{장비명} {기간_일}일 안에 고장날 확률 = {(1- kmf.predict(기간_일)).round(3)}')
# Out:
# 위생설비 30일 안에 고장날 확률 = 0.045

# %% [markdown]
# # 설치-처음고장 이용한 생존분석

# %% [markdown]
# ## 전체

# %%
장비명 = '소변기'
input_data = analysis_data[analysis_data['jangbi_class_nm_4']==장비명]


kmf = KaplanMeierFitter()
input_data.sort_values(by='설치-작업간격', ascending=True)
kmf.fit(durations=input_data['설치-작업간격'], event_observed=input_data['status'])
kmf.plot_survival_function()
plt.title(장비명+' 기간별 정상 확률')
기간_일 = 4270
print(f'{장비명} {기간_일}일 안에 처음 고장날 확률 = {(1- kmf.predict(기간_일)).round(3)}')
kmf.cumulative_density_.to_excel('위생설비 고장 시간.xlsx')
# Out:
# 소변기 4270일 안에 처음 고장날 확률 = 0.75

# %% [markdown]
# ## 고장이력이 있는 장비
# - 고장이 발생할때 > 기간별 고장 확률

# %%
장비명 = '소변기'
input_data = analysis_data[analysis_data['jangbi_class_nm_4']==장비명]
input_data = input_data[input_data['status']==1]

kmf = KaplanMeierFitter()
input_data.sort_values(by='설치-작업간격', ascending=True)
kmf.fit(durations=input_data['설치-작업간격'], event_observed=input_data['status'])
kmf.plot_survival_function()
plt.title('고장이력 있는 '+장비명+' 기간별 정상 확률')
기간_일 = 2000
print(f'{장비명} {기간_일}일 안에 고장날 확률 = {(1- kmf.predict(기간_일)).round(3)}')
kmf.cumulative_density_.to_excel('위생설비 고장이력있는 시간.xlsx')
# Out:
# 소변기 2000일 안에 고장날 확률 = 0.268

# %% [markdown]
# # 재발이력이 있는 장비
# - 재발할때 > 기간별 재발확률

# %%
장비명 = '위생설비'
input_data = analysis_data[analysis_data['jangbi_class_nm_3']==장비명]
input_data = input_data[input_data['재발유무']==1]

kmf = KaplanMeierFitter()
input_data.sort_values(by='작업-작업간격', ascending=True)
kmf.fit(durations=input_data['작업-작업간격'], event_observed=input_data['status'])
kmf.plot_cumulative_density()
plt.title('재발이력 있는 '+장비명+' 기간별 장애 확률')
기간_일 = 194
print(f'{장비명} {기간_일}일 안에 고장날 확률 = {(1- kmf.predict(기간_일)).round(3)}')
# Out:
# 위생설비 194일 안에 고장날 확률 = 0.897

# %%
kmf.cumulative_density_
# Out:
#           KM_estimate
# timeline
# 0.0          0.043974
# 1.0          0.083062
# 2.0          0.099349
# 3.0          0.115635
# 4.0          0.135179
# ...               ...
# 315.0        0.993485
# 316.0        0.995114
# 323.0        0.996743
# 340.0        0.998371
# 341.0        1.000000
#
# [199 rows x 1 columns]

# %%
input_data['fac_cd'].value_counts()
# Out:
# 200201020286    10
# 200201020055     8
# 200201010484     7
# 200201020041     7
# 200201010232     6
#                 ..
# 200201020052     1
# 200201030153     1
# 200201030068     1
# 200201040720     1
# 200201020043     1
# Name: fac_cd, Length: 336, dtype: int64

# %%
analysis_data[analysis_data['fac_cd']==200201020002]
# Out:
#            fac_cd                           fac_nm jangbi_class_nm_1  \
# 439  200201020002  (1)소-1-B1(남)B28-화장실)(소산실) 소변기 1                기계
#
#     jangbi_class_nm_2 jangbi_class_nm_3 jangbi_class_nm_4 fac_instdt  \
# 439          위생, 탱크설비              위생설비               소변기 2011-07-19
#
#     job_jisi_dt  설치-작업간격  작업-작업간격 job_cd job_nm   max_time  status  재발유무
# 439         NaT     4102     4102    NaN    NaN 2022-10-11       0     0

# %%
FMSX05_장비마스터[FMSX05_장비마스터['fac_cd'] == 200201020002]
# Out:
#      Unnamed: 0 comp_cd        fac_cd                           fac_nm  \
# 439         439    SEJO  200201020002  (1)소-1-B1(남)B28-화장실)(소산실) 소변기 1
#
#      class_cd  dept_cd      fac_model fac_spec   fac_plc     bd_cd  ...  \
# 439  20020102    10201  바닥형(0)/벽걸이(1)      NaN  B28-남화장실  SJ-01-01  ...
#
#     chk_edit_dt law_fac_yn jangbi_class_nm_1 jangbi_class_nm_2  \
# 439         NaN          N                기계          위생, 탱크설비
#
#     jangbi_class_nm_3 jangbi_class_nm_4 jangbi_class_cd_1 jangbi_class_cd_2  \
# 439              위생설비               소변기                20              2002
#
#      jangbi_class_cd_3 jangbi_class_cd_4
# 439             200201          20020102
#
# [1 rows x 47 columns]

# %%
FMSX05_장비마스터
# Out:
#        Unnamed: 0 comp_cd        fac_cd                       fac_nm  \
# 0               0    SEJO  200201040293  (3)세-1F-0(여)로비-화장실) 세면대 2대
# 1               1    SEJO  200201010257                   9F여1대변기(5)
# 2               2    SEJO  200202030001                        우수조#1
# 3               3    SEJO  200105080599               배기휀#76(EF-504)
# 4               4    SEJO  200202010001                        시수조#1
# ...           ...     ...           ...                          ...
# 40806       40806    SEJO  700101020004                  SCC 4호기 권상기
# 40807       40807    SEJO  700101020005                  SCC 5호기 권상기
# 40808       40808    SEJO  700101020006                  SCC 6호기 권상기
# 40809       40809    SEJO  700201010010                  SCC 7호기 제어반
# 40810       40810    SEJO  700201020001                  SCC 7호기 권상기
#
#        class_cd  dept_cd     fac_model     fac_spec     fac_plc       bd_cd  \
# 0      20020104    10201  자동(2)/수동(0)          청소수전       (여)로비         NaN
# 1      20020101    10201   CC-113(바닥형)  690*395*435  여-1(동) 화장실         NaN
# 2      20020203    10201           NaN          NaN         NaN         NaN
# 3      20010508    10201           NaN          NaN         NaN         NaN
# 4      20020201    10201           NaN          NaN         NaN         NaN
# ...         ...      ...           ...          ...         ...         ...
# 40806  70010102    10302        HS250K         12*6         NaN  SJ-SCJS-01
# 40807  70010102    10302        HS250K         12*6         NaN  SJ-SCJS-01
# 40808  70010102    10302        HS250K         12*6         NaN  SJ-SCJS-01
# 40809  70020101    10302    DZDLE-4300          NaN         NaN  SJ-SCJS-01
# 40810  70020102    10302      SDE-1504         12*6         NaN  SJ-SCJS-01
#
#        ... chk_edit_dt law_fac_yn jangbi_class_nm_1 jangbi_class_nm_2  \
# 0      ...         NaN          N                기계          위생, 탱크설비
# 1      ...         NaN          N                기계          위생, 탱크설비
# 2      ...         NaN          N                기계          위생, 탱크설비
# 3      ...         NaN          N                기계            공기조화설비
# 4      ...         NaN          N                기계          위생, 탱크설비
# ...    ...         ...        ...               ...               ...
# 40806  ...         NaN          N               승강기               승객용
# 40807  ...         NaN          N               승강기               승객용
# 40808  ...         NaN          N               승강기               승객용
# 40809  ...         NaN          N               승강기               화물용
# 40810  ...         NaN          N               승강기               화물용
#
#       jangbi_class_nm_3 jangbi_class_nm_4 jangbi_class_cd_1 jangbi_class_cd_2  \
# 0                  위생설비            세면대 수전                20              2002
# 1                  위생설비               대변기                20              2002
# 2                  탱크설비            우수 저장조                20              2002
# 3                  환기설비               환기팬                20              2001
# 4                  탱크설비            상수 저장조                20              2002
# ...                 ...               ...               ...               ...
# 40806                MR               권상기                70              7001
# 40807                MR               권상기                70              7001
# 40808                MR               권상기                70              7001
# 40809               로프식               제어반                70              7002
# 40810               로프식               권상기                70              7002
#
#        jangbi_class_cd_3 jangbi_class_cd_4
# 0                 200201          20020104
# 1                 200201          20020101
# 2                 200202          20020203
# 3                 200105          20010508
# 4                 200202          20020201
# ...                  ...               ...
# 40806             700101          70010102
# 40807             700101          70010102
# 40808             700101          70010102
# 40809             700201          70020101
# 40810             700201          70020102
#
# [40811 rows x 47 columns]
